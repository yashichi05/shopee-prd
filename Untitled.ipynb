# %%
from bs4 import BeautifulSoup
import requests
import json
url = "https://tw.bid.yahoo.com/tw/show/auctions?userID=Y3489416698"
my_headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'}
gotrq = requests.get(url,headers = my_headers)
soup = BeautifulSoup(gotrq.text, "html.parser") #"html.parser" html解析器 將html 轉為bs4格式操作
for item in soup.select(".listing-title"): #html 可以使用select 選擇想要的東西
    print(item.select("a")[0].text)
# Out:
#                                       日本進口【日本P&G;】 第三代 3D雙色洗衣膠球&補充包18個入 抗菌/淨白/柔軟 ☆綠光森林☆
#
#
#                                       日本進口【日本P&G;】 第三代 3D雙色洗衣膠球&補充包18個入 抗菌/淨白/柔軟 ☆綠光森林☆
#
#
#                                       德國製造 巧虎 兒童牙刷 6個月 2~4歲 6~12歲  ☆綠光森林☆
#
#
#                                       日本限定 SHISEIDO 【資生堂】THE AMENITY ECO SOAP 泡泡洗顏皂 18g 發票☆綠光森林☆
#
#
#                                       日本進口【日本P&G;】第三代香水香香豆 衣物芳香顆粒455ml／補充包 ☆綠光森林☆
#
#
#                                       【免運價】 珪藻土 日本の技【HIRO】(L)日本製 地墊 除臭 吸水 浴室 廁所用 ☆綠光森林☆
#
#
#                                       日本進口【P&G;】最新第三代3D【盒裝】18入洗衣膠球 ARIEL系列　雙色洗衣球 消臭/淨白 ☆綠光森林☆
#
#
#                                       日本進口【日本P&G;】最新日本第三代3D洗衣膠球【盒裝】18入 Bold系列　雙色洗衣球含柔軟精  ☆綠光森林☆
#
#
#                                       韓國No Brand紫心紅番薯洋芋片110g 紅薯洋芋片 紫色薯片 洋芋片 零食 ☆綠光森林☆
#
#
#                                       日本進口【日本P&G;】第三代香香豆 衣物芳香顆粒455ml／補充包 ☆綠光森林☆
#
#
# ...

# %%
from selenium import webdriver
import time
import os
import json
import requests

def getHttpResponseHeader(browser):
    for responseReceived in browser.get_log('performance'):
        try:
            response = json.loads(responseReceived[u'message'])[u'message'][u'params'][u'response']
            print
            if response[u'url'] == browser.current_url:
                return response[u'headers']
        except:
            pass
    return None

browser = webdriver.Chrome('chromedriver.exe') 
browser.get('https://shopee.tw/product/2019696/62726676/') 
#time.sleep(5)
print(getHttpResponseHeader(browser))

browser.close
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-1-69100d038ec9> in <module>()
#      19 browser.get('https://shopee.tw/product/2019696/62726676/')
#      20 #time.sleep(5)
# ---> 21 print(getHttpResponseHeader(browser))
#      22
#      23 browser.close
#
# <ipython-input-1-69100d038ec9> in getHttpResponseHeader(browser)
#       6
#       7 def getHttpResponseHeader(browser):
# ----> 8     for responseReceived in browser.get_log('performance'):
#       9         try:
#      10             response = json.loads(responseReceived[u'message'])[u'message'][u'params'][u'response']
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get_log(self, log_type)
#    1248             driver.get_log('server')
#    1249         """
# -> 1250         return self.execute(Command.GET_LOG, {'type': log_type})['value']
#
# ...

# %%
import requests
import json

page = 0 #第幾筆
prdid = [] #提取的商品ID

#發送每頁的GET 迴圈
while 1 != 2:
    page = page +100
    url = "https://shopee.tw/api/v2/search_items/?by=pop&limit=100&match_id=2019696&newest="+ str(page) +"&only_soldout=2&order=desc&page_type=shop"
    my_headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'}
    gotrq = requests.get(url,headers = my_headers)
    loadjson = json.loads(gotrq.text) #將Json轉成可用dict
    
    #提取每個頁面的商品ID
    for index in range(len(loadjson['items'])): 
        prdid.append(loadjson['items'][index]['itemid'])
        
    #如果到最後一頁跳出    
    if len(loadjson['items']) < 100:
        break


    
    
print(prdid)
# Out:
# [12747891, 56121377, 275338526, 145026582, 848617098, 433662324, 99144969, 718737446, 719664770, 153040405, 127514525, 62726676, 77602093, 617475065, 55520370, 792674056, 663440630, 139690974, 26113273, 878994411, 719802455, 83466576, 617390404, 471427707, 979493409, 1182652810, 125027043, 36297704, 341529325, 179415536, 309247068, 129023536, 836763608, 620921741, 75545444, 621963499, 129680129, 339943746, 599498873, 785156177, 140579804, 776071241, 56119736, 721352164, 115067894, 724636560, 350574103, 448722011, 25966395, 139511333, 775925178, 448926532, 1107526136, 724689551, 11933848, 406375879, 75427593, 339987960, 643967903, 92087660, 309268905, 41770368, 504763598, 408897267, 347557120, 96680222, 406354476, 820425135, 218630172, 99536399, 770016510, 1040054925, 235224531, 339917581, 20105173, 340043720, 455298332, 233831840, 663399432, 172392868, 785178607, 102225347, 340125561, 55529341, 340096277, 770250900, 309304071, 643914789, 30939287, 25961045, 982482516, 905001582, 7706
# ...

# %%
prdid2 = '146240780'
for index in range(len(prdid)):
    prdid2 = str(prdid[index])

    url = "https://shopee.tw/api/v1/item_detail/?item_id="+prdid2+"&shop_id=2019696"
    my_headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36',
             'referer': 'https://shopee.tw/product/2019696/'+prdid2+'/',
                  'x-api-source': 'pc',
                  'x-requested-with': 'XMLHttpRequest','dnt':'1',
                 'cookie': '_ga=GA1.2.1222824303.1530583395; cto_lwid=127f6ac1-75b9-4a9d-93d6-eafcefda5d8c; SPC_IA=-1; SPC_F=PagJQADZwTNZWbCpHAGMBWkqH3F6ms7y; REC_T_ID=4641d7e6-7e65-11e8-a3c1-d094660421c4; __BWfp=c1530583396388x753f1c076; SPC_T_IV="vL6GCz7ZXQOFasx1PQPkEw=="; SPC_T_ID="Nusq83Sb2UjKbHgi77uliV9a5GHj8Ccla+WwKr/Mo0Jq9OkYks3a3AxdCvanN07sZSNJ4c2KTSsaoq4/aLIGJS/oDU4VUHka7kEWIuyz6Kk="; _gac_UA-61915057-6=1.1531191657.CjwKCAjwj4zaBRABEiwA0xwsPzawodRhnK83p77FNeCJz04xtEhdrRjA8tUqQmBku-85XgQuR5mMWxoCL3QQAvD_BwE; _gcl_aw=GCL.1531191657.CjwKCAjwj4zaBRABEiwA0xwsPzawodRhnK83p77FNeCJz04xtEhdrRjA8tUqQmBku-85XgQuR5mMWxoCL3QQAvD_BwE; _atrk_siteuid=eBd_KScLMtDxk-HE; csrftoken=x7rqxca0C4FRD6DjQTtQyEJtAXcddDBG; __utma=88845529.1222824303.1530583395.1533689872.1533864015.5; __utmz=88845529.1533864015.5.2.utmcsr=seller.shopee.tw|utmccn=(referral)|utmcmd=referral|utmcct=/portal/sale; _gid=GA1.2.1766618031.1534122126; SPC_SI=urfiyoa32qjb69dskn3nujqmj089f4hd; SPC_SC_TK=ea678f81ee7ffa006ba2e2a4bd3a7538; SPC_SC_UD=2021177; SPC_U=2021177; bannerShown=true; root_csrftoken=d742f5e1-9de9-4efd-b072-0c36991c229d; _gat=1; SPC_EC="jlkA7SzxjI6ruBT/O7HXDZvNOzUehnqRELTHslXbqQxCiiFcaxubhWAgB5ae/6+QHFa5Zcd14BWLOXr2Ye/FQl8v54ZhLd2yJPGxYhuyL4fWjHlVxb32EYv7feXkr/N5U2BRF6tkvKagxMEKOd46mQ=="; _gat_gtm=1',
                 'accept': '*/*',
                  'accept-encoding': 'gzip, deflate, br',
                  'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7'}
    my_cookies = {}

    gotrq = requests.get(url,headers = my_headers,cookies = my_cookies)
    loadjson = json.loads(gotrq.text) #將Json轉成可用dict
    if (loadjson['models']):
        ar = []
        for i in range(len(loadjson['models'])):
            ar.append(loadjson['models'][i]['modelid'])
            ar.append(loadjson['models'][i]['stock'])
        print(loadjson['itemid'],ar)
    else:
        print(loadjson['itemid'],loadjson['stock'])
# Out:
# 12747891 [None, 15, None, 0, None, 0, None, 15, None, 0]
# 56121377 [None, 96]
# 275338526 [None, 52, None, 44, None, 45, None, 76, None, 48]
# 145026582 1
# 848617098 0
# 433662324 30
# 99144969 [None, 22, None, 26, None, 33, None, 28]
# 718737446 20
# 719664770 57
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
jar = requests.cookies.RequestsCookieJar()
jar.set('_ga'='GA1.2.1222824303.1530583395')
print(jar)
# Out:
#   File "<ipython-input-82-cdbb2ad42cc9>", line 2
#     jar.set('_ga'='GA1.2.1222824303.1530583395')
#            ^
# SyntaxError: keyword can't be an expression
