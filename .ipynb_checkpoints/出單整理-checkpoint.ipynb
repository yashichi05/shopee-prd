# %%
#蝦皮庫存表整理
import xlrd
import xlwt
import re
xlrd.Book.encoding = "utf8" #设置编码
data = xlrd.open_workbook(r"C:\Users\Owner\Downloads\Order.toship.20190201_20190223.xls")
table1 = data.sheet_by_index(0) #取第一张工作簿
rows_count = table1.nrows #取总行数

#nwb = xlwt.Workbook()# 新增EXCEL
#nsheet = nwb.add_sheet('google試算表格式')#新SHEET
#nsheet.write(0,0,'商品名稱')
#nwb.save('res.xls')

orderObj = []

#商品資訊
for i in range(1,rows_count): #迴圈
    orderObj.append({'orderdate':"",'orderID':"",'name':"",'tel':"",'account':"",'shipPrice':"",'ship':"",'shipID':"",'orderPrice':"",'discount':"",'credit':"",'prds':[]})#新增新的物件
    orderObj[i-1]['orderID'] = table1.cell_value(i,0) 
    orderObj[i-1]['orderdate'] = table1.cell_value(i,5) 
    orderObj[i-1]['name'] = table1.cell_value(i,20) 
    orderObj[i-1]['tel'] = table1.cell_value(i,21) 
    orderObj[i-1]['account'] = table1.cell_value(i,3) 
    orderObj[i-1]['shipPrice'] = table1.cell_value(i,7) 
    orderObj[i-1]['ship'] = table1.cell_value(i,22) 
    orderObj[i-1]['shipID'] = table1.cell_value(i,28) 
    orderObj[i-1]['orderPrice'] = table1.cell_value(i,8) 
    orderObj[i-1]['discount'] = table1.cell_value(i,11) 
    orderObj[i-1]['credit'] = table1.cell_value(i,25) 
    text = table1.cell_value(i,12) 
    if text != '商品資訊':
        text = text.replace("	","") #去除tab 大空格
        for ii in re.split("\[[0-9]\]",text): #分割"[數字]"資料
            if ii: #如果ii有資料則輸出
                orderObj[i-1]['prds'].append({'prdText':ii.replace("\n","").strip()}) #放入prd陣列中，-1是因為i是從第二列開始

# %%
orderObj
# Out:
# [{'orderdate': '2019-02-22 14:20',
#   'orderID': '190222141968WGU',
#   'name': '黃*賢',
#   'tel': '886915***696',
#   'account': 'anthony0622',
#   'shipPrice': '30.00',
#   'ship': 'OK Mart',
#   'shipID': '59048440782',
#   'orderPrice': '445.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:白麝香 (超取限制14瓶); 價格: $ 130; 數量: 1; 商品選項貨號: 4535304275893;"},
#    {'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:蘋果梨 (超取限制14瓶); 價格: $ 130; 數量: 1; 商品選項貨號: 4535304282884;"},
#    {'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:麝香櫻花 (超取限制14瓶); 價格: $ 155; 數量: 1; 商品選項貨號: 4535304291626;"}]},
#  {'orderdate': '2019-02-22 15:16',
#   'orderID': '19022215146DJEX',
#   'name': '陳*合',
#   'tel': '886920***763',
#   'account': 'maychen0516',
#   'shipPrice': '60.00',
#   'ship': '7-11',
#   'shipID': 'E43276731579',
#   'orderPrice': '326.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': '商品名稱:✨現貨快出🔜【EDISON】兒童學習湯匙組附收納盒 橘藍 / 紫粉 🌳 綠光森林 🌳; 商品選項名稱:紫粉; 價格: $ 190; 數量: 1; 商品選項貨號: 4544742916428;'},
#    {'prdText': '商品名稱:💯㊣附發票  SUNSTAR三詩達 兒童巧虎牙刷6個月 2~4歲 4~6歲 6~12歲  隨機出貨🌳 綠光森林 🌳; 商品選項名稱:6個月; 價格: $ 38; 數量: 1; 商品選項貨號: 4901616214842;'},
#    {'prdText': '商品名稱:💯㊣附發票  SUNSTAR三詩達 兒童巧虎牙刷6個月 2~4歲 4~6歲 6~12歲  隨機出貨🌳 綠光森林 🌳; 商品選項名稱:2~4歲; 價格: $ 38; 數量: 1; 商品選項貨號: 4901616214835;'}]},
#  {'orderdate': '2019-02-22 15:46',
#   'orderID': '19022215456G9KN',
#   'name': '曾*婷',
#   'tel': '886955***506',
#   'account': 'budin',
#   'shipPrice': '60.00',
#   'ship': '7-11',
#   'shipID': 'E43276605981',
#   'orderPrice': '252.00',
#   'discount': '0.00',
#   'credit': '蝦皮錢包',
#   'prds': [{'prdText': "商品名稱:💯㊣附發票🔜日本John's Blend 香氛片 白麝香 紅酒 茉莉 香片 衣櫥芳香 房間室內 🌳 綠光森林 🌳; 商品選項名稱:白茉莉/麝香茉莉; 價格: $ 48; 數量: 4; 商品選項貨號: 4535304287506;"}]},
#  {'orderdate': '2019-02-22 16:48',
#   'orderID': '19022216476NETD',
#   'name': '李*芳',
#   'tel': '886912***725',
#   'account': 's_flower',
#   'shipPrice': '30.00',
#   'ship': 'OK Mart',
#   'shipID': '28546624110',
#   'orderPrice': '555.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票 🔜 熊野 四季椿油保濕滋潤 洗髮精 潤髮乳 沐浴乳 護髮素 🌳 綠光森林 🌳; 商品選項名稱:洗髮精600ml; 價格: $ 175; 數量: 1; 商品選項貨號: 4513574017245;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜 熊野 四季椿油保濕滋潤 洗髮精 潤髮乳 沐浴乳 護髮素 🌳 綠光森林 🌳; 商品選項名稱:護髮乳600ml; 價格: $ 175; 數量: 2; 商品選項貨號: 4513574017252;'}]},
#  {'orderdate': '2019-02-22 18:34',
#   'orderID': '19022218336W62P',
#   'name': 'E**H',
#   'tel': '886908***134',
#   'account': 'ekfial',
#   'shipPrice': '60.00',
#   'ship': '7-11',
#   'shipID': 'E43276628487',
#   'orderPrice': '378.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票  熊野 salon link沙龍級洗髮精1000ml 乾性髮質 / 油性髮質 ㊣正品 🌳 綠光森林 🌳; 商品選項名稱:保濕洗髮精(粉)(四瓶以上限宅配); 價格: $ 159; 數量: 1; 商品選項貨號: 4513574014152;'},
#    {'prdText': '商品名稱:💯㊣附發票  熊野 salon link沙龍級洗髮精1000ml 乾性髮質 / 油性髮質 ㊣正品 🌳 綠光森林 🌳; 商品選項名稱:保濕潤絲精(桃)(四瓶以上限宅配); 價格: $ 159; 數量: 1; 商品選項貨號: 4513574014169;'}]},
#  {'orderdate': '2019-02-22 18:56',
#   'orderID': '1902221854604TK',
#   'name': '胡*華',
#   'tel': '886934***117',
#   'account': 't74432000',
#   'shipPrice': '45.00',
#   'ship': '萊爾富',
#   'shipID': '9EN919336502',
#   'orderPrice': '1185.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:白麝香 (超取限制14瓶); 價格: $ 130; 數量: 4; 商品選項貨號: 4535304275893;"},
#    {'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:麝香櫻花 (超取限制14瓶); 價格: $ 155; 數量: 4; 商品選項貨號: 4535304291626;"}]},
#  {'orderdate': '2019-02-22 19:38',
#   'orderID': '190222193763F87',
#   'name': '黃*儀',
#   'tel': '886910***858',
#   'account': 'ne_iiiii',
#   'shipPrice': '60.00',
#   'ship': '7-11',
#   'shipID': 'E43276586456',
#   'orderPrice': '365.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': "商品名稱:💯㊣附發票 🔜  John's Blend 香氛噴霧280ml 白麝香 蘋果梨 白茉莉 紅酒香 🌳 綠光森林 🌳; 商品選項名稱:白麝香 宅配限15個; 價格: $ 175; 數量: 1; 商品選項貨號: 4535304275831;"},
#    {'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:白麝香 (超取限制14瓶); 價格: $ 130; 數量: 1; 商品選項貨號: 4535304275893;"}]},
#  {'orderdate': '2019-02-22 19:59',
#   'orderID': '19022219586532S',
#   'name': '洪*琪',
#   'tel': '886919***586',
#   'account': 'imhvicky',
#   'shipPrice': '60.00',
#   'ship': '7-11',
#   'shipID': 'E43276473714',
#   'orderPrice': '510.00',
#   'discount': '0.00',
#   'credit': '信用卡',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票 🔜OSK 可橫放冷水壺2.2L／深藍色  🌳 綠光森林 🌳; 價格: $ 225; 數量: 2; 主商品貨號: 4970825081804 ;'}]},
#  {'orderdate': '2019-02-22 20:48',
#   'orderID': '1902222046691NE',
#   'name': '劉*喬',
#   'tel': '886953***533',
#   'account': 'fanny730530',
#   'shipPrice': '60.00',
#   'ship': '萊爾富',
#   'shipID': '9EN919335237',
#   'orderPrice': '320.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:白麝香 (超取限制14瓶); 價格: $ 130; 數量: 2; 商品選項貨號: 4535304275893;"}]},
#  {'orderdate': '2019-02-22 20:52',
#   'orderID': '190222205069BQD',
#   'name': '張*捷',
#   'tel': '886932***091',
#   'account': 'jack19921102',
#   'shipPrice': '60.00',
#   'ship': '全家',
#   'shipID': 'SHP1963044512',
#   'orderPrice': '450.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:白茉莉 (超取限制14瓶); 價格: $ 130; 數量: 3; 商品選項貨號: 4535304287681;"}]},
#  {'orderdate': '2019-02-22 22:10',
#   'orderID': '19022222086GDGK',
#   'name': '薛*敏',
#   'tel': '886930***948',
#   'account': 'lynn811208',
#   'shipPrice': '30.00',
#   'ship': 'OK Mart',
#   'shipID': '87858420170',
#   'orderPrice': '575.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:白麝香 (超取限制14瓶); 價格: $ 130; 數量: 2; 商品選項貨號: 4535304275893;"},
#    {'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:紅酒香 (超取限制14瓶); 價格: $ 130; 數量: 1; 商品選項貨號: 4535304287674;"},
#    {'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:麝香櫻花 (超取限制14瓶); 價格: $ 155; 數量: 1; 商品選項貨號: 4535304291626;"}]},
#  {'orderdate': '2019-02-22 22:24',
#   'orderID': '19022222226HYEB',
#   'name': '蔡*純',
#   'tel': '886912***766',
#   'account': 'rikipink521',
#   'shipPrice': '30.00',
#   'ship': 'OK Mart',
#   'shipID': '56554106682',
#   'orderPrice': '340.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票 🔜 SUNSTAR 三詩達 巧虎兒童牙膏70g 草莓 葡萄 日本製  🌳 綠光森林 🌳; 商品選項名稱:草莓; 價格: $ 55; 數量: 1; 商品選項貨號: 4901616009622;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜 SUNSTAR 三詩達 巧虎兒童牙膏70g 草莓 葡萄 日本製  🌳 綠光森林 🌳; 商品選項名稱:葡萄; 價格: $ 55; 數量: 3; 商品選項貨號: 4901616009516;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜 ECHO 粉彩指甲剪8.5cm 3色隨機 🌳 綠光森林 🌳; 商品選項名稱:顏色隨機出貨; 價格: $ 45; 數量: 2; 主商品貨號: 4991203144744;'}]},
#  {'orderdate': '2019-02-22 22:44',
#   'orderID': '19022222426M9UG',
#   'name': '李*妤',
#   'tel': '886910***619',
#   'account': 's150353',
#   'shipPrice': '60.00',
#   'ship': '7-11',
#   'shipID': 'E43276460857',
#   'orderPrice': '443.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票 🔜 ASVEL  密封米罐2kg  🌳 綠光森林 🌳; 商品選項名稱:米罐 (超商限2個); 價格: $ 178; 數量: 1; 主商品貨號: 4974908750991;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜小林製藥 鞋用除菌消臭噴霧250ml 🌳 綠光森林 🌳; 價格: $ 135; 數量: 1; 主商品貨號: 4987072061756;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜 第一石鹼 浴廁除菌除霉噴霧 400ml 補充瓶 🌳 綠光森林 🌳; 商品選項名稱:有噴頭 超商限12瓶; 價格: $ 70; 數量: 1; 商品選項貨號: 4902050423135;'}]},
#  {'orderdate': '2019-02-22 22:58',
#   'orderID': '19022222576NYTA',
#   'name': '丁*雲',
#   'tel': '886952***979',
#   'account': 'cloud5956',
#   'shipPrice': '30.00',
#   'ship': 'OK Mart',
#   'shipID': '36886984640',
#   'orderPrice': '486.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票  SUNSTAR三詩達 兒童巧虎牙刷6個月 2~4歲 4~6歲 6~12歲  隨機出貨🌳 綠光森林 🌳; 商品選項名稱:2~4歲; 價格: $ 38; 數量: 12; 商品選項貨號: 4901616214835;'}]},
#  {'orderdate': '2019-02-22 23:25',
#   'orderID': '19022223236RPUC',
#   'name': '蔡宛錚',
#   'tel': '886927657339',
#   'account': 'sophia7374',
#   'shipPrice': '0.00',
#   'ship': '賣家宅配',
#   'shipID': '',
#   'orderPrice': '480.00',
#   'discount': '0.00',
#   'credit': '信用卡',
#   'prds': [{'prdText': '商品名稱:✨現貨快出🔜免運費【LIVEWELL】多功能手提式野餐桌 5色 日本製 🌳 綠光森林 🌳; 商品選項名稱:抹茶色; 價格: $ 480; 數量: 1; 商品選項貨號: 4905310061382;'}]},
#  {'orderdate': '2019-02-22 23:43',
#   'orderID': '19022223426TN1Q',
#   'name': '李*廉',
#   'tel': '886987***629',
#   'account': 'dddiretear',
#   'shipPrice': '30.00',
#   'ship': 'OK Mart',
#   'shipID': '64965626477',
#   'orderPrice': '416.00',
#   'discount': '0.00',
#   'credit': '信用卡',
#   'prds': [{'prdText': '商品名稱:✨現貨快出🔜【EDISON】幼兒九個月學習湯叉組附收納盒 桃紅 黃 🌳 綠光森林 🌳; 商品選項名稱:桃紅; 價格: $ 128; 數量: 1; 商品選項貨號: 4544742916251;'},
#    {'prdText': '商品名稱:✨現貨快出🔜【EDISON】幼兒九個月學習湯叉組附收納盒 桃紅 黃 🌳 綠光森林 🌳; 商品選項名稱:黃; 價格: $ 128; 數量: 1; 商品選項貨號: 4544742916268;'},
#    {'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:蘋果梨 (超取限制14瓶); 價格: $ 130; 數量: 1; 商品選項貨號: 4535304282884;"}]},
#  {'orderdate': '2019-02-23 00:32',
#   'orderID': '190223003160RNW',
#   'name': '葉姝妘',
#   'tel': '886937139323',
#   'account': 'shuyun.yeh',
#   'shipPrice': '80.00',
#   'ship': '賣家宅配',
#   'shipID': '',
#   'orderPrice': '1209.00',
#   'discount': '0.00',
#   'credit': '信用卡',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票 🔜 MUSE 自動泡沫洗手機+洗手液 綠茶 廚房 鮮柚 🌳 綠光森林 🌳; 商品選項名稱:綠茶組合包裝(1機+1補); 價格: $ 410; 數量: 1; 商品選項貨號: 800456;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜 MUSE 自動泡沫洗手機+洗手液 綠茶 廚房 鮮柚 🌳 綠光森林 🌳; 商品選項名稱:香皂香補充瓶; 價格: $ 165; 數量: 1; 商品選項貨號: 4906156800715;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜 ASVEL  密封米罐2kg  🌳 綠光森林 🌳; 商品選項名稱:米罐 (超商限2個); 價格: $ 178; 數量: 1; 主商品貨號: 4974908750991;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜 小久保 鑽石鏡面刷 藍色  鑽石流理台刷 綠色 🌳 綠光森林 🌳; 商品選項名稱:鑽石流理台刷(綠); 價格: $ 38; 數量: 1; 商品選項貨號: 4956810236787;'},
#    {'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:白麝香 (超取限制14瓶); 價格: $ 130; 數量: 2; 商品選項貨號: 4535304275893;"},
#    {'prdText': '商品名稱:✨現貨快出🔜【INOMATA】牛奶鍋造型量杓 白色 橘藍 🌳 綠光森林 🌳; 商品選項名稱:白色; 價格: $ 39; 數量: 2; 商品選項貨號: 4905596113768;'}]},
#  {'orderdate': '2019-02-23 00:47',
#   'orderID': '1902230047623T0',
#   'name': '廖*瑜',
#   'tel': '886933***005',
#   'account': 'dior823919',
#   'shipPrice': '30.00',
#   'ship': 'OK Mart',
#   'shipID': '49121588516',
#   'orderPrice': '520.00',
#   'discount': '0.00',
#   'credit': '信用卡',
#   'prds': [{'prdText': '商品名稱:✨現貨快出🔜日本 柳屋YANAGIYA HAIR TONIC 髮根 養髮液 清爽 柑橘 240ML 🌳綠光森林🌳; 商品選項名稱:髮根養髮液240ml; 價格: $ 245; 數量: 1; 商品選項貨號: 4903018113235;'},
#    {'prdText': '商品名稱:✨現貨快出🔜日本 柳屋YANAGIYA HAIR TONIC 髮根 養髮液 清爽 柑橘 240ML 🌳綠光森林🌳; 商品選項名稱:髮根養髮液240ml 柑橘; 價格: $ 245; 數量: 1; 商品選項貨號: 4903018113518;'}]},
#  {'orderdate': '2019-02-23 01:14',
#   'orderID': '190223011063VVF',
#   'name': '方湘瑋',
#   'tel': '886927337558',
#   'account': 'fangweiwei',
#   'shipPrice': '80.00',
#   'ship': '賣家宅配',
#   'shipID': '',
#   'orderPrice': '4570.00',
#   'discount': '0.00',
#   'credit': '銀行轉帳',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票 🔜 SHISEIDO 資生堂 ECO SOAP 泡泡洗顏皂 18g 🌳 綠光森林 🌳; 商品選項名稱:洗顏皂(金色包裝); 價格: $ 20; 數量: 1; 商品選項貨號: JL000001;'},
#    {'prdText': "商品名稱:💯㊣附發票🔜日本John's Blend 香氛片 白麝香 紅酒 茉莉 香片 衣櫥芳香 房間室內 🌳 綠光森林 🌳; 商品選項名稱:白麝香; 價格: $ 48; 數量: 15; 商品選項貨號: 4535304275800;"},
#    {'prdText': "商品名稱:💯㊣附發票 🔜【John's Blend】居家香氛膏135g 白麝香 蘋果梨 紅酒香 白茉莉 🌳 綠光森林 🌳; 商品選項名稱:白麝香 一箱30瓶; 價格: $ 3,750; 數量: 1; 商品選項貨號: 4535304275893*30;"}]},
#  {'orderdate': '2019-02-23 01:52',
#   'orderID': '1902230152653K1',
#   'name': '林*達',
#   'tel': '886915***009',
#   'account': 'd8360786',
#   'shipPrice': '60.00',
#   'ship': '7-11',
#   'shipID': 'E43276454301',
#   'orderPrice': '320.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': "商品名稱:💯㊣附發票 🔜 正品日本 John's Blend 香氛膏/芳香膠 135g 房間室內芳香 🌳 綠光森林 🌳; 商品選項名稱:白麝香 (超取限制14瓶); 價格: $ 130; 數量: 2; 商品選項貨號: 4535304275893;"}]},
#  {'orderdate': '2019-02-23 02:26',
#   'orderID': '190223022565QWF',
#   'name': '賴*如',
#   'tel': '886932***708',
#   'account': 'lailufi',
#   'shipPrice': '60.00',
#   'ship': '萊爾富',
#   'shipID': '9EN919335873',
#   'orderPrice': '561.00',
#   'discount': '0.00',
#   'credit': '貨到付款',
#   'prds': [{'prdText': '商品名稱:💯㊣附發票 🔜  PONIKASEI 伸縮衣架1入 粉色 藍色 隨機出貨 🌳 綠光森林 🌳; 價格: $ 49; 數量: 2; 主商品貨號: 4962964105107;'},
#    {'prdText': '商品名稱:✨現貨快出🔜【COGIT】浴室防霉片 🌳 綠光森林 🌳; 價格: $ 218; 數量: 1; 主商品貨號: 4969133267789;'},
#    {'prdText': '商品名稱:💯㊣附發票 🔜 N47 紗窗刷 日本 Nippon Seal 乾濕二用 紗窗紗門 清潔刷 🌳 綠光森林 🌳; 價格: $ 185; 數量: 1; 主商品貨號: 4902391047663 ;'}]}]
