', '4984909500754', '4900896128870', '4562351032506', '4562351032513', '4901559226124', '4905343015185', '4956810801862', '4901070908684', '45170850', '45170867', '4901070124763', '4901070125852', '4901070126538', '4571169852961', '4987072061756', '4902407013071', '4902407013088', '4902407013064', '4903301194194', '4903301527039', '4903301720355', '4903301745525', '4904766110309', '4516825004377', '4931546422420', '4931546422727', '4931546422710', '4989082061351', '4987009156876', '4991203155108', '4977554229354', '4582423049911', '4582423067915', '4535304275800', '4535304282860', '4535304282877', '4535304275831', '4535304287513', '4535304275893', '4535304282884', '4535304287674', '4535304286318', '4901070124473', '4901070124466', '4901070122530', '4901070125418', '4901070125401', '4901070124497', '4901070124480', '4901070119301']
#sys.stdout = io.TextIOWrapper(sys.stdout.buffer,encoding='utf8') #改變標準輸出的默認編碼

#登錄後才能訪問的網頁
url = 'http://www.daiyi.url.tw/a/index.php?route=account/login' 
postdata = {'email':'daiyi1190@gmail.com','password':'123456'}
newSession = requests.Session() #新的session
#post 資料
#沿用session
res = newSession.post(url,data = postdata)
for i in iso:
    
    res = newSession.get('http://www.daiyi.url.tw/a/index.php?route=product/search&filter_name='+i)
    soup = BeautifulSoup(res.text, "html.parser")
    name = soup.select('.name')
    pirce = soup.select('.price-new')
    txt = ''
    for ii in range(len(name)):
        txt = txt+pirce[ii].text+'**'+name[ii].text+"	"
    print(i+"	"+txt)
# Out:
# 4902011744910	NT$90**4902011744910 【大王製紙】女童游泳學習尿布-M×3枚入 日本製	NT$1,020**4902011744910 【大王製紙】女童游泳學習尿布-M×3枚入 日本製 ☆12包/一箱出貨(單包$85)，不拆箱。
# 4902011744934	NT$1,020**4902011744934 【大王製紙】女童游泳學習尿布-L×3枚入  日本製 ☆12包/一箱出貨(單包$85)，不拆箱。	NT$90**4902011744934 【大王製紙】女童游泳學習尿布-L×3枚入 日本製
# 4902011744958	NT$90**4902011744958 【大王製紙】女童游泳學習尿布-Big×3枚入 日本製	NT$1,020**4902011744958 【大王製紙】女童游泳學習尿布-Big×3枚入 日本製 ☆12包/一箱出貨(單包$85)，不拆箱。
# 4902011744903	NT$90**4902011744903 【大王製紙】男童游泳學習尿布-M×3枚入	NT$1,020**4902011744903 【大王製紙】男童游泳學習尿布-M×3枚入 日本製 ☆12包/一箱出貨(單包$85)，不拆箱。
# 4902011744927	NT$90**4902011744927 【大王製紙】男童游泳學習尿布-L×3枚入 日本製	NT$1,020**4902011744927 【大王製紙】男童游泳學習尿布-L×3枚入 日本製 ☆12包/一箱出貨(單包$85)，不拆箱。
# 4902011744941	NT$90**4902011744941 【大王製紙】男童游泳學習尿布-Big×3枚入 日本製	NT$1,020**4902011744941 【大王製紙】男童游泳學習尿布-Big×3枚入 日本製 ☆12包/一箱出貨(單包$85)，不拆箱。
# 4904551100607	NT$130**4904551100607 【MIYOSHI】無添加泡泡洗手乳350ml 日本製	NT$1,500**4904551100607 【MIYOSHI】無添加泡泡洗手乳350ml 日本製 ☆12瓶/一組出貨(單瓶$125)，不拆組。
# ...

# %%
', '480'], ['4582423045296', '480'], ['4582423049911', '480'], ['4582423067915', '480'], ['4994793002968', '899'], ['4904810812562', '168'], ['4904810812616', '168'], ['4904810812623', '168'], ['4904810812630', '168'], ['4904810812647', '168'], ['4904810818465', '168'], ['4904810821564', '168'], ['4904810821267', '168'], ['JK687788', '45'], ['JK000051', '45'], ['JE000001', '45'], ['JE687680', '45'], ['JE687665', '45'], ['JE687657', '45'], ['4527749139359', '179'], ['4527749139366', '179'], ['4527749139373', '179'], ['4527749139380', '179'], ['4527749372213', '179'], ['4527749372220', '179'], ['4527749372237', '179'], ['4901498115367', '79'], ['4535304275800', '48'], ['4535304282860', '48'], ['4535304287506', '48'], ['4535304287490', '48'], ['4535304282877', '170'], ['4535304275831', '170'], ['4535304287520', '170'], ['4535304287513', '170'], ['4535304275893', '140'], ['4535304282884', '140'], ['4535304287674', '140'], ['4535304286318', '210'], ['', '175'], ['', '55'], ['', '195'], ['', '400'], ['4901070124473', '215'], ['4901070124466', '215'], ['4901070122530', '215'], ['4901070125388', '199'], ['4901070125395', '199'], ['4901070125418', '145'], ['4901070125401', '145'], ['4901070124497', '145'], ['4901070124480', '145'], ['4901070119301', '145'], ['4525636186356', '109'], ['4990936287025', '175'], ['4990936287032', '175'], ['4990936287049', '175'], ['4990936287063', '175'], ['4990936287070', '175'], ['4990936289128', '175'], ['4990936287087', '175'], ['4990936287094', '175'], ['4990936287100', '175'], ['4990936289173', '175'], ['4990936289180', '175'], ['4990936289197', '175'], ['4544042814608x60', '230'], ['4544042814608x40', '155'], ['4544042814608x20', '85']]
newSession = requests.Session()
for i in SheetAry:
    res = newSession.get('https://jpgo.tw/?product_cat=&s='+i[0]+'&post_type=product')
    soup = BeautifulSoup(res.text, "html.parser")
    data = soup.select(".price-wrapper span")
    try:
        print(i[0]+'	'+i[1]+'	'+data[0].text)
    except:
        print(i[0]+'	'+i[1]+'	沒有')
# Out:
# 4513574025806	160	沒有
# 4513574023062	90	沒有
# 4582400833113	250	沒有
# 4902895039683	288	沒有
# 4901301321510	338	沒有
# 4901301321527	338	沒有
# 4901301321534	338	NT$329 NT$279
# 4976551911484	260	沒有
# 4976551007491	260	沒有
# 4976551108716	260	沒有
# 4903018183856	460	沒有
# 4903018113235	245	沒有
# 4903018113518	245	沒有
# 4903018261103	149	沒有
# 4903018261219	169	沒有
# 4903018262018	225	沒有
# 3760061221093	185	沒有
# 3700392139476	250	沒有
# JL000001	20	沒有
# JL000002	20	沒有
# JL000003	45	沒有
# 4901872449651	190	沒有
# 4982757912057	250	沒有
# 8809091070969	79	沒有
# 4976631605005	125	沒有
# 4976631649191	145	沒有
# 4976631478234	150	沒有
# 4976631478296	189	NT$200
# 4549549770754	229	沒有
# 4549549298302	229	沒有
# 4549813937999	229	沒有
# 4550084221335	229	沒有
# 4571263110967	830	沒有
# 4571263111186	1400	沒有
# 4976631894263	179	沒有
# 4976631894225	119	沒有
# 4904551043119	40	NT$59 NT$49
# 4961989107608	350	沒有
# 4902468226120	265	沒有
# 4902508102346	180	沒有
# 4969133235658	259	沒有
# 4969133375651	365	沒有
# 4969133925702	249	沒有
# ...

# %%
import requests
import sys
import io

#sys.stdout = io.TextIOWrapper(sys.stdout.buffer,encoding='utf8') #改變標準輸出的默認編碼

#登錄後才能訪問的網頁
url = 'http://www.daiyi.url.tw/a/index.php' 

#瀏覽器登錄後得到的cookie，也就是剛才複製的字符串
cookie_str = r'language=tw; currency=TWD; PHPSESSID=8494c038ee939fd5e59a8454cd9c7595'

#把cookie字符串處理成字典，以便接下來使用
cookies = {}
for line in cookie_str.split(';'): #cookie_str.split(';') 依分號 分割成陣列 並列出

    key, value = line.split('=', 1) #將陣列依序指派給key value
    cookies[key] = value #新增物件
    
session = requests.Session()
res = session.get(url,cookies=cookies)


    
print(res.text)

# %%
#請動WEBDRIVER
#https://selenium-python.readthedocs.io/api.html
import time
from selenium import webdriver
from selenium.webdriver.common.touch_actions import TouchActions
options = webdriver.ChromeOptions() #新增選項
#options.add_argument("--window-size=1920,10800")
chromeDriver = webdriver.Chrome(chrome_options=options)
chromeDriver.get('https://shopee.tw/')
chromeDriver.maximize_window()
#for row in chromeDriver.get_cookies():
#    print(row)

# %%
#登入
#我的cookies = [{'domain': '.shopee.tw', 'expiry': 2171255390.071453, 'httpOnly': True, 'name': 'SPC_EC', 'path': '/', 'secure': False, 'value': '"07PSm4EiuR25rdOSHw74lcmQiv+uVkCGugRMgK+X8BAfr5nlTeRCdvKa3lWOEq0gO6LQ8wVUpVKO0djtR1p8HvtEZhwv7GWtzOzTMY9YGKPM7r6ypyrAWD018TfR4TvStgDpY0Hi8J4zyLw6BUWhTw=="'}]
#公司
cookies = [{'domain': '.shopee.tw', 'expiry': 2171255390.071453, 'httpOnly': True, 'name': 'SPC_EC', 'path': '/', 'secure': False, 'value': '"xlRsycPNaLKz0TmHMDNAg31jRA3we/VyO9qG6+iFzqQLcz3791FVCAxBYsNyuyW58HGRKeIFya5irIWeERRIYqlFqUSH4bQ1b+m2/eyo37pUaM/wcRktaJbvv/PsVbtprjPwmYqznIx64c2BQwqq2g=="'}]
chromeDriver.delete_all_cookies()
for cookieData in cookies:
    chromeDriver.add_cookie(cookieData)
#for row in chromeDriver.get_cookies():
#chromeDriver.get('https://shopee.tw/')
chromeDriver.get("https://seller.shopee.tw/portal/sale?type=completed")
#for row in chromeDriver.get_cookies():
#    print(row)

# %%
#評價
def dosomething():
    for x in range(10): #迴圈十次
        gotbutton = chromeDriver.find_elements_by_class_name("ct-actions")#找評價紐
        for i in gotbutton:
            if i.text == "評價":#開始評價
                i.location_once_scrolled_into_view #移動到所選 
                tact = TouchActions(chromeDriver) #向下偏移
                tact.scroll(0,200).perform()
                i.click()
                time.sleep(1)
                star = chromeDriver.find_elements_by_class_name("editable")
                star[0].click()
                textarea = chromeDriver.find_elements_by_class_name("ember-text-area")
                textarea[0].send_keys("感謝您的購買，歡迎再次光臨，也不要忘了給賣場評價喔。")
                submitframe = chromeDriver.find_element_by_css_selector(".lm-actions")
                submitframe = submitframe.find_elements_by_tag_name("div")
                submitframe[0].click() #0是評價 1是取消紐
                time.sleep(1)
        #找下一頁按鈕
        nextpage = chromeDriver.find_elements_by_class_name("shopee-pagination")
        nextpage = nextpage[0].find_elements_by_tag_name("li")
        for ni in nextpage: #按下一頁
            if ni.text == "下一頁":
                ni.click()
        time.sleep(5)

while len(chromeDriver.get_log('driver')) == 0: #當瀏覽器關閉 則停止
    try:
        dosomething()
    except:
        chromeDriver.refresh()
        time.sleep(5)

        
#JS寫法document.getElementsByClassName("Qr0MNi")[0].scrollIntoView()

# %%
import requests
import sys
import io

#sys.stdout = io.TextIOWrapper(sys.stdout.buffer,encoding='utf8') #改變標準輸出的默認編碼

#登錄後才能訪問的網頁
url = 'http://seller.pcstore.com.tw/S188431702/plist_dt.htm?s=S188431702&c=&skw=&pg=2&sr=1&pp=50' 

#瀏覽器登錄後得到的cookie，也就是剛才複製的字符串
cookie_str = r'cbj=IqhLsP6..LOKMq6kVcXtnWgBVcXtnqojj'
my_headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 Safari/537.36'}


#把cookie字符串處理成字典，以便接下來使用
cookies = {}
for line in cookie_str.split(';'): #cookie_str.split(';') 依分號 分割成陣列 並列出

    key, value = line.split('=', 1) #將陣列依序指派給key value
    cookies[key] = value #新增物件
print(cookies)
session = requests.Session()
res = session.get(url,cookies=cookies,headers = my_headers)
r

    
print(res.text)

# %%
from __future__ import print_function
from bs4 import BeautifulSoup
from selenium import webdriver
from googleapiclient.discovery import build
from httplib2 import Http
from oauth2client import file, client, tools
import requests
import json
import time

def getsheet(sheetrange):
    """Shows basic usage of the Sheets API.
    Prints values from a sample spreadsheet.
    """
    store = file.Storage('token.json')
    creds = store.get()
    if not creds or creds.invalid:
        flow = client.flow_from_clientsecrets('credentials.json', SCOPES)
        creds = tools.run_flow(flow, store)
    service = build('sheets', 'v4', http=creds.authorize(Http()))

    # Call the Sheets API
    SPREADSHEET_ID = '1SzGbZKDNyviZsIUmI4Z0MeLovsDrx6zHcYTZhulBcyQ'
    RANGE_NAME = sheetrange
    result = service.spreadsheets().values().get(spreadsheetId=SPREADSHEET_ID,
                                                range=RANGE_NAME).execute()
    values = result.get('values', [])
    if not values:
        print('No data found.')
    else:
        return values
a = getsheet('工作表1!A:A')

# %%
ary=[]
for i in a:
    ary.append(i[0])
print(ary)
# Out:
# ['國際條碼', '4902011744910', '4902011744934', '4902011744958', '4902011744903', '4902011744927', '4902011744941', '4904551100607', '4904551100614', '4902430674980', '4902430724838', '4902430675024', '4902430674997', '4902430674973', '4902430675000', '4902430674966', '4987072066447', '4983239160492', '4904766130215', '4904766130246', '4901616009622', '4901616009516', '4991203130631', '4973381251544', '4973381251537', '4562351019002', '4562351019316', '4902430754989', '4902430755023', '4902430752039', '4902430752091', '4902430689724', '4902430689687', '4902430675864', '4902430675970', '4902430689748', '4902430675994', '4902430676052', '4902430523547', '4901797100033', '4901797100019', '4902430736237', '4902430736220', '4902430736244', '4901301321824', '4901301321831', '4537130101278', '4902883210018', '4968909061408', '4901610157732', '4971710386356', '4971710386363', '4513574009103', '4582400831003', '4987241145638', '4513574019737', '4961691104254', '4961691103127', '4961691104223', '49
# ...
